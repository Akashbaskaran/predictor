# %%
#! /usr/bin/python
# Copyright (c) 2015, Rethink Robotics, Inc.

# Using this CvBridge Tutorial for converting
# ROS images to OpenCV2 images
# http://wiki.ros.org/cv_bridge/Tutorials/ConvertingBetweenROSImagesAndOpenCVImagesPython

# Using this OpenCV2 tutorial for saving Images:
# http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_image_display/py_image_display.html

# rospy for the subscriber
import rospy
# ROS Image message
from sensor_msgs.msg import Image
# ROS Image message -> OpenCV2 image converter
from cv_bridge import CvBridge, CvBridgeError
# OpenCV2 for saving an image
import sys
import cv2

# Instantiate CvBridge
bridge = CvBridge()
import glob
import os
import pandas as pd
import datetime
import matplotlib.pyplot as plt

import matplotlib.image as mpimg
import numpy as np

from keras.models import Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, Lambda, Cropping2D, ELU
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.convolutional import Convolution2D
from keras import regularizers, optimizers, initializers
from keras.callbacks import EarlyStopping,ModelCheckpoint, TensorBoard, Callback
print("Done importing data")


def image_callback(img):
    print("1")
    img = CvBridge().imgmsg_to_cv2(img)
    #cv_image = CvBridge().imgmsg_to_cv2(img,desired_encoding=str("passthrough"))
    print("Received an image!")
    print(img)
    plt.show(img)
    # #np_arr = np.fromstring(msg, np.uint8) 
    # #np_img = np_arr.reshape((480, 640, 3)) 
    # print("0")
    # #image=image[50:140, 0:320]
    # print("1")
    # # Resize to 200x66 pixel
    # image = cv2.resize(msg, (200,66), interpolation=cv2.INTER_AREA)
    # print("2")
    # images=np.reshape(image, (1, 66,200,3))    
    # # image.reshape()
    # val=model.predict(images)
    # print("3")
    # print(val)

def main():
    rospy.init_node('image_listener')
    print('I am listening')
    import sys
    print(sys.version)
    # Define your image topic
    image_topic = "/synchronized_image_raw"
    # model=load_model('/home/akashbaskaran/CNN/model-e007.h5')

    # print(model.summary())

    # Set up your subscriber and define its callback
    rospy.Subscriber(image_topic, Image, image_callback)
    # Spin until ctrl + c
    rospy.spin()

if __name__ == '__main__':
    main()
# Out:
# Using TensorFlow backend.
# Done importing data
# I am listening
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]
# 1
# bayer_rggb8
# Received an image!
# [[ 27 235  83 ...  91  52  91]
#  [102 166 103 ... 150  91 147]
#  [ 62 101  62 ...  92  52  90]
#  ...
#  [204 255 207 ... 226 179 223]
#  [161 204 159 ... 183 142 179]
#  [205 255 204 ... 229 184 225]]
# 1
# bayer_rggb8
# Received an image!
# [[ 28  62 187 ...  89  53  90]
#  [103 165 103 ... 149  92 147]
#  [ 63 103  62 ...  91  55  89]
#  ...
#  [203 255 205 ... 229 182 227]
#  [160 202 159 ... 183 140 181]
#  [204 255 204 ... 230 184 233]]
# [ERROR] [1558055651.908749]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055652.056979]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 28 134  39 ...  92  52  91]
#  [104 167 102 ... 150  91 147]
#  [ 60 103  62 ...  92  54  91]
#  ...
#  [204 255 204 ... 231 182 227]
#  [158 206 160 ... 181 142 181]
#  [203 255 204 ... 234 182 228]]
# 1
# bayer_rggb8
# Received an image!
# [[ 28 205 147 ...  91  55  90]
#  [102 169 104 ... 147  89 147]
#  [ 64 104  63 ...  92  53  91]
#  ...
#  [206 255 207 ... 219 176 212]
#  [159 206 163 ... 176 138 176]
#  [206 255 203 ... 227 181 224]]
# [ERROR] [1558055652.157254]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055652.297891]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 29  21   0 ...  93  54  90]
#  [103 169 103 ... 150  90 148]
#  [ 64 104  63 ...  92  53  91]
#  ...
#  [204 255 203 ... 231 181 225]
#  [161 205 157 ... 186 143 181]
#  [206 255 203 ... 233 185 227]]
# 1
# bayer_rggb8
# Received an image!
# [[ 29  92 103 ...  92  54  92]
#  [105 172 103 ... 148  90 152]
#  [ 63 104  64 ...  91  53  91]
#  ...
#  [207 255 206 ... 231 185 227]
#  [162 207 159 ... 186 146 184]
#  [205 255 203 ... 232 186 231]]
# 1
# bayer_rggb8
# Received an image!
# [[ 29 163 212 ...  91  54  92]
#  [106 167 102 ... 149  89 149]
#  [ 63 105  65 ...  90  55  91]
#  ...
#  [205 255 204 ... 228 181 218]
#  [161 206 160 ... 182 143 179]
#  [207 255 205 ... 232 184 224]]
# [ERROR] [1558055652.447530]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055652.525000]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055652.646292]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 29 235  64 ...  92  53  91]
#  [105 172 105 ... 149  90 151]
#  [ 66 106  64 ...  91  54  90]
#  ...
#  [202 255 203 ... 238 184 234]
#  [159 205 158 ... 188 144 184]
#  [206 255 201 ... 237 188 234]]
# 1
# bayer_rggb8
# Received an image!
# [[ 30  62 170 ...  90  54  92]
#  [106 171 105 ... 155  90 149]
#  [ 64 105  67 ...  92  54  91]
#  ...
#  [203 255 203 ... 235 185 230]
#  [156 206 159 ... 188 144 182]
#  [205 255 204 ... 233 188 233]]
# [ERROR] [1558055652.849778]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055652.964027]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 30 134  20 ...  91  55  92]
#  [105 169 106 ... 149  90 149]
#  [ 64 106  65 ...  91  55  92]
#  ...
#  [203 255 205 ... 232 184 229]
#  [161 203 159 ... 187 146 183]
#  [204 255 203 ... 231 188 230]]
# 1
# bayer_rggb8
# Received an image!
# [[ 30 205 128 ...  91  56  93]
#  [104 173 105 ... 151  91 148]
#  [ 65 107  64 ...  92  54  91]
#  ...
#  [204 255 203 ... 233 186 228]
#  [159 204 160 ... 187 146 182]
#  [206 255 203 ... 233 185 233]]
# [ERROR] [1558055653.143844]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055653.241669]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 31  20 232 ...  92  56  92]
#  [106 172 106 ... 151  91 150]
#  [ 66 106  65 ...  93  52  91]
#  ...
#  [205 255 204 ... 236 187 233]
#  [158 203 159 ... 188 146 186]
#  [205 255 202 ... 233 186 236]]
# 1
# bayer_rggb8
# Received an image!
# [[ 31  92  84 ...  90  55  91]
#  [106 170 107 ... 149  90 148]
#  [ 67 108  65 ...  92  55  90]
#  ...
#  [206 255 205 ... 237 187 228]
#  [161 205 159 ... 188 146 184]
#  [205 255 202 ... 239 187 233]]
# [ERROR] [1558055653.431611]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055653.541429]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 31 163 192 ...  92  54  92]
#  [107 171 105 ... 150  89 149]
#  [ 64 105  67 ...  92  54  91]
#  ...
#  [204 255 204 ... 231 183 228]
#  [160 202 160 ... 186 144 183]
#  [206 255 205 ... 234 187 236]]
# 1
# bayer_rggb8
# Received an image!
# [[ 31 235  40 ...  93  53  92]
#  [107 172 108 ... 151  91 148]
#  [ 67 108  67 ...  93  56  90]
#  ...
#  [205 255 205 ... 233 188 234]
#  [159 204 158 ... 185 146 188]
#  [205 255 202 ... 234 186 236]]
# [ERROR] [1558055653.642892]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558
: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 35  20 193 ...  94  58  95]
#  [103 165 102 ... 154  94 155]
#  [ 63 102  64 ...  96  57  94]
#  ...
#  [203 255 203 ... 236 185 230]
#  [158 201 156 ... 187 146 184]
#  [203 255 203 ... 236 187 234]]
# 1
# bayer_rggb8
# Received an image!
# [[ 35  92  41 ...  97  58  98]
#  [102 162  99 ... 161  95 156]
#  [ 62 103  62 ...  96  57  95]
#  ...
#  [200 255 204 ... 223 178 224]
#  [156 202 156 ... 181 143 178]
#  [203 255 201 ... 230 181 223]]
# 1
# bayer_rggb8
# Received an image!
# [[ 35 163 149 ...  98  59  96]
#  [121 185 122 ... 157  95 159]
#  [ 86 122  85 ...  97  59  98]
#  ...
#  [200 255 201 ... 218 175 218]
#  [157 199 157 ... 180 141 177]
#  [205 255 200 ... 225 180 221]]
# [ERROR] [1558055655.433273]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055655.533242]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055655.634964]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 35 235   1 ...  97  57  95]
#  [126 182 123 ... 160  96 156]
#  [ 91 127  91 ...  96  57  98]
#  ...
#  [200 255 201 ... 227 181 222]
#  [156 199 156 ... 182 143 181]
#  [198 255 199 ... 227 182 229]]
# 1
# bayer_rggb8
# Received an image!
# [[ 36  62 106 ...  98  59  98]
#  [101 162 100 ... 159  98 155]
#  [ 61 100  60 ... 100  58  98]
#  ...
#  [199 255 201 ... 226 182 225]
#  [157 201 155 ... 185 145 184]
#  [199 254 199 ... 234 187 227]]
# [ERROR] [1558055655.848178]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055655.936939]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 36 133 214 ... 101  61 101]
#  [100 161  97 ... 163 100 160]
#  [ 60  97  59 ... 101  61 100]
#  ...
#  [201 255 199 ... 228 180 220]
#  [157 200 156 ... 185 144 180]
#  [202 254 197 ... 228 184 229]]
# 1
# bayer_rggb8
# Received an image!
# [[ 36 205  66 ... 105  62 102]
#  [100 162  99 ... 165 104 166]
#  [ 61  99  61 ... 105  65 104]
#  ...
#  [199 255 201 ... 228 183 224]
#  [155 200 155 ... 186 145 183]
#  [199 255 198 ... 233 187 229]]
# [ERROR] [1558055656.148255]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055656.234457]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 37  20 170 ... 126  86 126]
#  [103 162 101 ... 188 125 182]
#  [ 66 104  64 ... 123  80 120]
#  ...
#  [200 251 201 ... 227 181 224]
#  [157 200 156 ... 183 142 181]
#  [200 252 199 ... 232 184 230]]
# 1
# bayer_rggb8
# Received an image!
# [[ 37  92  23 ... 184 141 184]
#  [103 163 101 ... 246 182 242]
#  [ 62 104  62 ... 184 142 182]
#  ...
#  [200 255 200 ... 220 176 217]
#  [153 199 156 ... 181 140 177]
#  [198 255 199 ... 224 180 220]]
# 1
# bayer_rggb8
# Received an image!
# [[ 37 163 130 ... 182 141 183]
#  [ 97 159  97 ... 244 181 242]
#  [ 61  99  61 ... 185 142 185]
#  ...
#  [198 254 198 ... 231 182 225]
#  [152 197 153 ... 188 146 184]
#  [198 254 198 ... 237 189 231]]
# [ERROR] [1558055656.431859]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055656.531582]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055656.633631]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055656.829729]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 37 234 234 ... 124  81 126]
#  [ 97 157  97 ... 189 124 187]
#  [ 59  96  58 ... 124  82 130]
#  ...
#  [197 253 201 ... 226 183 225]
#  [153 197 155 ... 187 145 185]
#  [197 252 196 ... 233 187 232]]
# 1
# bayer_rggb8
# Received an image!
# [[ 38  62  86 ... 121  80 125]
#  [ 94 154  95 ... 181 118 182]
#  [ 57  95  58 ... 117  75 117]
#  ...
#  [197 252 196 ... 231 183 228]
#  [156 197 153 ... 190 145 187]
#  [198 250 194 ... 235 190 235]]
# [ERROR] [1558055656.929698]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558
: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 41  20 130 ... 114  72 118]
#  [ 88 141  90 ... 173 114 175]
#  [ 53  90  54 ... 111  69 113]
#  ...
#  [190 246 192 ... 244 193 242]
#  [150 191 150 ... 192 152 193]
#  [193 247 192 ... 242 194 239]]
# 1
# bayer_rggb8
# Received an image!
# [[ 41  91 235 ... 101  61 102]
#  [ 89 146  89 ... 165 100 166]
#  [ 54  88  56 ... 101  62 101]
#  ...
#  [192 243 191 ... 234 191 234]
#  [149 191 146 ... 192 153 192]
#  [193 245 189 ... 243 195 239]]
# 1
# bayer_rggb8
# Received an image!
# [[ 41 163  87 ... 101  61 102]
#  [ 87 144  88 ... 162 101 163]
#  [ 53  88  54 ... 101  61 101]
#  ...
#  [190 237 190 ... 237 190 237]
#  [148 192 149 ... 192 151 192]
#  [192 246 190 ... 246 193 243]]
# [ERROR] [1558055658.441588]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055658.531661]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055658.634856]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 41 234 195 ... 101  60 101]
#  [ 87 141  85 ... 165 101 165]
#  [ 52  87  51 ... 103  61 102]
#  ...
#  [187 239 189 ... 240 193 239]
#  [149 189 146 ... 193 150 193]
#  [190 239 189 ... 247 194 242]]
# 1
# bayer_rggb8
# Received an image!
# [[ 42  62  43 ... 101  61 103]
#  [ 86 141  84 ... 165 100 165]
#  [ 52  85  49 ... 101  61 102]
#  ...
#  [188 236 190 ... 237 193 239]
#  [147 188 147 ... 195 150 190]
#  [188 240 191 ... 242 194 240]]
# [ERROR] [1558055658.845680]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# ...
#  [194 200 192 ... 209 200 206]]
# 1
# bayer_rggb8
# Received an image!
# [[ 78 203 144 ...  92  64  92]
#  [ 74 100  74 ... 123  90 122]
#  [ 54  74  52 ...  91  64  90]
#  ...
#  [195 201 195 ... 210 203 206]
#  [183 195 182 ... 205 194 202]
#  [193 202 193 ... 209 203 207]]
# [ERROR] [1558055677.105829]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055677.218760]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 79  18 248 ...  91  64  90]
#  [ 73 101  75 ... 121  90 121]
#  [ 52  74  54 ...  89  63  90]
#  ...
#  [194 202 196 ... 205 199 203]
#  [180 193 185 ... 201 192 199]
#  [193 205 194 ... 207 201 206]]
# 1
# bayer_rggb8
# Received an image!
# [[ 79  90 100 ...  91  64  90]
#  [ 75 102  74 ... 121  90 117]
#  [ 52  74  52 ...  91  64  89]
#  ...
#  [191 201 194 ... 206 200 201]
#  [180 191 181 ... 203 189 199]
#  [193 201 193 ... 209 201 204]]
# [ERROR] [1558055677.434324]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055677.529945]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 79 161 208 ...  92  64  89]
#  [ 74 102  72 ... 123  90 120]
#  [ 54  75  52 ...  90  65  91]
#  ...
#  [193 201 193 ... 208 199 204]
#  [184 194 180 ... 200 190 199]
#  [197 196 194 ... 207 201 205]]
# 1
# bayer_rggb8
# Received an image!
# [[ 79 233  56 ...  91  64  92]
#  [ 74 101  72 ... 120  89 121]
#  [ 52  74  52 ...  91  65  91]
#  ...
#  [194 203 193 ... 206 199 199]
#  [185 194 181 ... 201 190 199]
#  [193 200 192 ... 206 202 202]]
# 1
# bayer_rggb8
# Received an image!
# [[ 80  60 165 ...  90  64  90]
#  [ 74 101  73 ... 121  89 118]
#  [ 53  73  53 ...  90  64  90]
#  ...
#  [192 197 195 ... 207 196 201]
#  [181 193 183 ... 201 188 199]
#  [194 200 192 ... 206 201 201]]
# [ERROR] [1558055677.721007]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055677.808282]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055677.918493]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 80 132  17 ...  89  64  89]
#  [ 75 101  73 ... 121  87 119]
#  [ 55  74  52 ...  90  65  89]
#  ...
#  [196 200 192 ... 209 202 205]
#  [182 193 180 ... 201 195 200]
#  [195 201 192 ... 208 202 211]]
# 1
# bayer_rggb8
# Received an image!
# [[ 80 203 121 ...  90  64  90]
#  [ 74 100  73 ... 119  88 120]
#  [ 53  75  51 ...  91  63  92]
#  ...
#  [191 198 193 ... 210 200 205]
#  [180 191 182 ... 203 189 199]
#  [192 199 191 ... 208 202 207]]
# [ERROR] [1558055678.120407]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055678.209576]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 81  18 229 ...  89  64  90]
#  [ 75  99  73 ... 120  89 118]
#  [ 55  74  54 ...  90  64  90]
#  ...
#  [195 200 191 ... 205 197 202]
#  [182 194 180 ... 201 186 197]
#  [194 202 192 ... 206 200 202]]
# 1
# bayer_rggb8
# Received an image!
# [[ 81  90  81 ...  88  64  90]
#  [ 73  99  74 ... 120  90 116]
#  [ 53  75  52 ...  88  64  89]
#  ...
#  [193 200 196 ... 207 197 201]
#  [182 192 183 ... 200 192 200]
#  [195 200 192 ... 209 201 203]]
# [ERROR] [1558055678.425059]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055678.516137]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 81 161 185 ...  91  63  89]
#  [ 73 101  73 ... 118  89 118]
#  [ 52  74  54 ...  89  64  88]
#  ...
#  [192 200 193 ... 209 202 200]
#  [180 194 183 ... 200 188 200]
#  [195 202 193 ... 206 202 206]]
# 1
# bayer_rggb8
# Received an image!
# [[ 81 233  38 ...  89  63  88]
#  [ 73 101  75 ... 119  87 116]
#  [ 53  74  54 ...  89  63  87]
#  ...
#  [193 199 194 ... 209 199 203]
#  [182 193 181 ... 201 190 200]
#  [196 199 190 ... 209 200 205]]
# [ERROR] [1558055678.705294]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055678.850431]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 82 131 251 ...  87  62  89]
#  [ 76 101  72 ... 120  87 120]
#  [ 54  74  54 ...  88  62  89]
#  ...
#  [193 202 191 ... 205 199 205]
#  [181 193 179 ... 202 188 199]
#  [195 199 192 ... 202 200 205]]
# 1
# bayer_rggb8
# Received an image!
# [[ 82 203 101 ...  89  61  89]
#  [ 75 101  75 ... 120  88 119]
#  [ 54  74  55 ...  88  62  89]
#  ...
#  [195 200 193 ... 205 200 203]
#  [181 193 181 ... 199 188 198]
#  [193 200 193 ... 207 203 208]]
# [ERROR] [1558055679.203488]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055679.326168]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 1
# bayer_rggb8
# Received an image!
# [[ 83  18 209 ...  88  63  87]
#  [ 75 101  73 ... 118  88 117]
#  [ 54  74  56 ...  88  62  87]
#  ...
#  [193 200 189 ... 207 199 205]
#  [182 193 183 ... 203 191 198]
#  [194 200 192 ... 204 201 207]]
# 1
# bayer_rggb8
# Received an image!
# [[ 83  90  59 ...  87  62  88]
#  [ 74 102  74 ... 119  87 119]
#  [ 53  75  51 ...  87  63  88]
#  ...
#  [190 201 194 ... 203 200 202]
#  [185 193 183 ... 202 193 199]
#  [194 202 190 ... 205 202 202]]
# [ERROR] [1558055679.463604]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [ERROR] [1558055679.533197]: bad callback: <function image_callback at 0x7f294ecd7510>
# Traceback (most recent call last):
#   File "/opt/ros/kinetic/lib/python2.7/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "<ipython-input-1-edbd11e881f9>", line 48, in image_callback
#     plt.show(img)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 254, in show
#     return _show(*args, **kw)
#   File "/home/akashbaskaran/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py", line 45, in show
#     if close and Gcf.get_all_fig_managers():
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
